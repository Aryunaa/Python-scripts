# %%
import pandas as 
#genus_unidentified

# %%
feature_table_filtered = pd.read_csv("/home/ariuna/Downloads/microbiom/R_opist/todo_filtering/biom_out/changes_little/feature-table_meta.txt",sep='\t')

# %%
feature_table_filtered
# Out:
#                                       #OTU ID_taxonomy  90123  90126  90134  \
# 0         60db910f53985b0b5e99357c4a1c8a5a_k__Bacteria    158    559    281
# 1         d85252b00c32f9615e3dd682bf078361_k__Bacteria      0    395    223
# 2         4c4bb3e1de89bc5984aef9703061e4e2_k__Bacteria     55    429    218
# 3         68888c1036c0fe16d080a259cf285e95_k__Bacteria      0    393    181
# 4         04d4c2d62309c3671773ff10317c49fe_k__Bacteria      0    322    167
# 5         bfc4ac8b549fd3890d3ce90845604318_k__Bacteria      0    352    147
# 6         0f5dd6197dcabd67f0a60223a6adc55e_k__Bacteria      0    353    143
# 7         538ccbf0d3212b2d276579b5e6a25b96_k__Bacteria      0    283    156
# 8         29cc6e322db526cd333c3879d012ca71_k__Bacteria      0    255    179
# 9         d79f17833093691e7fa30b24bde8d1f9_k__Bacteria    185     51    218
# 10        7b743444fde0237b109ce6aff717614b_k__Bacteria      0     38    212
# ...

# %%
df=feature_table_filtered
df
# Out:
#                                       #OTU ID_taxonomy  90123  90126  90134  \
# 0         60db910f53985b0b5e99357c4a1c8a5a_k__Bacteria    158    559    281
# 1         d85252b00c32f9615e3dd682bf078361_k__Bacteria      0    395    223
# 2         4c4bb3e1de89bc5984aef9703061e4e2_k__Bacteria     55    429    218
# 3         68888c1036c0fe16d080a259cf285e95_k__Bacteria      0    393    181
# 4         04d4c2d62309c3671773ff10317c49fe_k__Bacteria      0    322    167
# 5         bfc4ac8b549fd3890d3ce90845604318_k__Bacteria      0    352    147
# 6         0f5dd6197dcabd67f0a60223a6adc55e_k__Bacteria      0    353    143
# 7         538ccbf0d3212b2d276579b5e6a25b96_k__Bacteria      0    283    156
# 8         29cc6e322db526cd333c3879d012ca71_k__Bacteria      0    255    179
# 9         d79f17833093691e7fa30b24bde8d1f9_k__Bacteria    185     51    218
# 10        7b743444fde0237b109ce6aff717614b_k__Bacteria      0     38    212
# ...

# %%
otu_king=[]
ph = []
cl = []
order = []
fam = []
gen = []
sp = []

# %%
import re

# %%
for item in df['#OTU ID_taxonomy']:
    item = re.split(r'; ',item)
    print(len(item))
    #print(type(item))
    if(len(item)<2):
        item.append('phylum_unidentified')
        item.append('class_unidentified')
        item.append('order_unidentified')
        item.append('family_unidentified')
        item.append('genus_unidentified')
        item.append('species_unidentified')
    if(len(item)<3):
        item.append('class_unidentified')
        item.append('order_unidentified')
        item.append('family_unidentified')
        item.append('genus_unidentified')
        item.append('species_unidentified')
    if(len(item)<4):
        item.append('order_unidentified')
        item.append('family_unidentified')
        item.append('genus_unidentified')
        item.append('species_unidentified')
    if(len(item)<5):
        item.append('family_unidentified')
        item.append('genus_unidentified')
        item.append('species_unidentified')
    if(len(item)<6):
        item.append('genus_unidentified')
        item.append('species_unidentified')
    if(len(item)<7):
        item.append('species_unidentified')
    print(item)
    
    otu_king.append(item[0])
    ph.append(item[1])
    cl.append(item[2])
    order.append(item[3])
    fam.append(item[4])
    gen.append(item[5])
    sp.append(item[6])
# Out:
# 1
# ['60db910f53985b0b5e99357c4a1c8a5a_k__Bacteria', 'phylum_unidentified', 'class_unidentified', 'order_unidentified', 'family_unidentified', 'genus_unidentified', 'species_unidentified']
# 1
# ['d85252b00c32f9615e3dd682bf078361_k__Bacteria', 'phylum_unidentified', 'class_unidentified', 'order_unidentified', 'family_unidentified', 'genus_unidentified', 'species_unidentified']
# 1
# ['4c4bb3e1de89bc5984aef9703061e4e2_k__Bacteria', 'phylum_unidentified', 'class_unidentified', 'order_unidentified', 'family_unidentified', 'genus_unidentified', 'species_unidentified']
# 1
# ['68888c1036c0fe16d080a259cf285e95_k__Bacteria', 'phylum_unidentified', 'class_unidentified', 'order_unidentified', 'family_unidentified', 'genus_unidentified', 'species_unidentified']
# 1
# ['04d4c2d62309c3671773ff10317c49fe_k__Bacteria', 'phylum_unidentified', 'class_unidentified', 'order_unidentified', 'family_unidentified', 'genus_unidentified', 'species_unidentified']
# 1
# ...

# %%
result = re.split(r'y', 'Analytics')
print(result)
# Out:
# ['Anal', 'tics']

# %%
len(otu_king)
# Out:
# 453

# %%
if ((len(ph)==453) & (len(cl)==453) & (len(order)==453) & (len(fam)==453) & (len(gen)==453) & (len(sp)==453)):
    print('alright,go on')
# Out:
# alright,go on

# %%
tclass=[]
torder=[]
tfam=[]
tgen=[]
tspec=[]
tph = []
for st in ph:
    if (len(st)<4):
        print(st)
        st='class_unidentified'
    tph.append(st)

for st in cl:
    if (len(st)<4):
        print(st)
        st='class_unidentified'
    tclass.append(st)
        
for st in order:
    if (len(st)<4):
        print(st)
        st='order_unidentified'
    torder.append(st)       
for st in fam:
    if (len(st)<4):
        print(st)
        st='family_unidentified'
    tfam.append(st)   
for st in gen:
    if (len(st)<4):
        print(st)
        st='genus_unidentified'
    tgen.append(st)
# Out:
# c__
# o__
# f__
# f__
# f__
# f__
# f__
# f__
# f__
# f__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__
# g__

# %%
for st in sp:
    if (len(st)<4):
        print(st)
        st='species_unidentified'
    tspec.append(st)
# Out:
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__
# s__

# %%
len(tspec)
# Out:
# 453

# %%
df['#OTU ID_Kingdom']=otu_king
df['Phylum']=tph
df['Class']=tclass
df['Order']=torder
df['Family']=tfam
df['Genus']=tgen
df['Species']=tspec

# %%
df
# Out:
#                                       #OTU ID_taxonomy  90123  90126  90134  \
# 0         60db910f53985b0b5e99357c4a1c8a5a_k__Bacteria    158    559    281
# 1         d85252b00c32f9615e3dd682bf078361_k__Bacteria      0    395    223
# 2         4c4bb3e1de89bc5984aef9703061e4e2_k__Bacteria     55    429    218
# 3         68888c1036c0fe16d080a259cf285e95_k__Bacteria      0    393    181
# 4         04d4c2d62309c3671773ff10317c49fe_k__Bacteria      0    322    167
# 5         bfc4ac8b549fd3890d3ce90845604318_k__Bacteria      0    352    147
# 6         0f5dd6197dcabd67f0a60223a6adc55e_k__Bacteria      0    353    143
# 7         538ccbf0d3212b2d276579b5e6a25b96_k__Bacteria      0    283    156
# 8         29cc6e322db526cd333c3879d012ca71_k__Bacteria      0    255    179
# 9         d79f17833093691e7fa30b24bde8d1f9_k__Bacteria    185     51    218
# 10        7b743444fde0237b109ce6aff717614b_k__Bacteria      0     38    212
# ...

# %%
tgen[2]
# Out:
# 'genus_unidentified'

# %%
dtspec = []
i=0
for t in tspec:
    if(t!='species_unidentified'):
        t=tgen[i]+'_'+tspec[i]
    dtspec.append(t)
    i+=1

# %%
dtspec
# Out:
# ['species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'g__Hafnia_s__alvei',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'g__Pseudomonas_s__fragi',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
#  'species_unidentified',
# ...

# %%
df['Species']=dtspec

# %%
df
# Out:
#                                       #OTU ID_taxonomy  90123  90126  90134  \
# 0         60db910f53985b0b5e99357c4a1c8a5a_k__Bacteria    158    559    281
# 1         d85252b00c32f9615e3dd682bf078361_k__Bacteria      0    395    223
# 2         4c4bb3e1de89bc5984aef9703061e4e2_k__Bacteria     55    429    218
# 3         68888c1036c0fe16d080a259cf285e95_k__Bacteria      0    393    181
# 4         04d4c2d62309c3671773ff10317c49fe_k__Bacteria      0    322    167
# 5         bfc4ac8b549fd3890d3ce90845604318_k__Bacteria      0    352    147
# 6         0f5dd6197dcabd67f0a60223a6adc55e_k__Bacteria      0    353    143
# 7         538ccbf0d3212b2d276579b5e6a25b96_k__Bacteria      0    283    156
# 8         29cc6e322db526cd333c3879d012ca71_k__Bacteria      0    255    179
# 9         d79f17833093691e7fa30b24bde8d1f9_k__Bacteria    185     51    218
# 10        7b743444fde0237b109ce6aff717614b_k__Bacteria      0     38    212
# ...

# %%
df.to_csv("/home/ariuna/Downloads/microbiom/R_opist/todo_filtering/biom_out/changes_little/feature-table_meta_mod.txt",sep='\t')
